# %%
import hssm
import arviz as az
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Modules for path issues
# import sys
# nb_path = '/content/drive/MyDrive/USC/Classes/3rd Year/PSYC573/project'
# sys.path.insert(0, nb_path)
# %cd '/content/drive/MyDrive/USC/Classes/3rd Year/PSYC573/project'
import os
import glob

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('all_cleaned/flanker_all_hssm.csv')

# %%
data.head()
# Out:
#    participant_id   trial_type  resp_corr        rt  response   mean_rt  \
# 0            1903    congruent          1  0.841311         1  0.945541
# 1            1903  incongruent          1  1.105856        -1  1.020937
# 2            1903  incongruent          1  1.151826         1  1.020937
# 3            1903    congruent          1  0.710728        -1  0.945541
# 4            1903  incongruent          1  0.956795         1  1.020937
#
#       sd_rt  exclude_thresh  exclude_trial  exclude_part school group
# 0  0.158969             2.4              0             0    UIC  rMDD
# 1  0.151395             2.4              0             0    UIC  rMDD
# 2  0.151395             2.4              0             0    UIC  rMDD
# 3  0.158969             2.4              0             0    UIC  rMDD
# 4  0.151395             2.4              0             0    UIC  rMDD

# %%
print('There are ' + str(len(data.participant_id.unique())) + ' participants.')
print(str(len(data.groupby(['group'])['participant_id'].unique()['HC'])) + ' HCs.')
print(str(len(data.groupby(['group'])['participant_id'].unique()['rMDD'])) + ' people with rMDD.')
print(str(len(data.groupby(['group'])['participant_id'].unique()['SI'])) + ' people with SI.')
# Out:
# There are 131 participants.
# 51 HCs.
# 51 people with rMDD.
# 29 people with SI.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Model Setup

# %%
param_v_int = {"name": "v",
           "formula": "v ~ 1 + group:trial_type + (1|participant_id)"
           }
param_a_int = {"name": "a",
               "formula": "a ~ 1 + group:trial_type + (1|participant_id)"
               }
param_t_int = {"name": "t",
               "formula": "t ~ 1 + group:trial_type + (1|participant_id)"
               }
m_int = hssm.HSSM(data=data,
                  model="ddm",
                  include=[param_v_int, param_a_int, param_t_int],
                  hierarchical=True,
                  prior_settings="safe")
# Out:
# Model initialized successfully.

# %%
m_int
# Out:
# Hierarchical Sequential Sampling Model
# Model: ddm
#
# Response variable: rt,response
# Likelihood: analytical
# Observations: 6230
#
# Parameters:
#
# v:
#     Formula: v ~ 1 + group:trial_type + (1|participant_id)
#     Priors:
#         v_Intercept ~ Normal(mu: 2.0, sigma: 3.0)
#         v_trial_type ~ Normal(mu: 0.0, sigma: 0.25)
#         v_group:trial_type ~ Normal(mu: 0.0, sigma: 0.25)
#         v_1|participant_id ~ Normal(mu: 0.0, sigma: Weibull(alpha: 1.5, beta: 0.3))
#     Link: identity
#     Explicit bounds: (-inf, inf)
#
# a:
#     Formula: a ~ 1 + group:trial_type + (1|participant_id)
#     Priors:
#         a_Intercept ~ Gamma(mu: 1.5, sigma: 0.75)
#         a_trial_type ~ Normal(mu: 0.0, sigma: 0.25)
#         a_group:trial_type ~ Normal(mu: 0.0, sigma: 0.25)
#         a_1|participant_id ~ Normal(mu: 0.0, sigma: Weibull(alpha: 1.5, beta: 0.3))
#     Link: identity
#     Explicit bounds: (0.0, inf)
#
# z:
#     Formula: z ~ 1 + (1|participant_id)
#     Priors:
#         z_Intercept ~ Beta(alpha: 10.0, beta: 10.0)
#         z_1|participant_id ~ Normal(mu: 0.0, sigma: Weibull(alpha: 1.5, beta: 0.3))
#     Link: identity
#     Explicit bounds: (0.0, 1.0)
#
# t:
#     Formula: t ~ 1 + group:trial_type + (1|participant_id)
#     Priors:
#         t_Intercept ~ Gamma(mu: 0.2, sigma: 0.2)
#         t_trial_type ~ Normal(mu: 0.0, sigma: 0.25)
#         t_group:trial_type ~ Normal(mu: 0.0, sigma: 0.25)
#         t_1|participant_id ~ Normal(mu: 0.0, sigma: Weibull(alpha: 1.5, beta: 0.3))
#     Link: identity
#     Explicit bounds: (0.0, inf)
#
#
# Lapse probability: 0.05
# Lapse distribution: Uniform(lower: 0.0, upper: 20.0)

# %% [markdown]
# ## Running the Model

# %%
"""
4 chains, (`draws`+`tune`) iterations, burn-in of `tune`.
Sampler: NUTS
"""

chains = 4
draws = 5000
burn = 5000

m_int_trace = m_int.sample(draws=draws, chains=chains, tune=burn, cores=4)
# Out:
# Using default initvals.
#
# The model has already been sampled. Overwriting the previous inference object. Any previous reference to the inference object will still point to the old object.
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [v_Intercept, v_trial_type, v_group:trial_type, v_1|participant_id_sigma, v_1|participant_id_offset, a_Intercept, a_trial_type, a_group:trial_type, a_1|participant_id_sigma, a_1|participant_id_offset, z_Intercept, z_1|participant_id_sigma, z_1|participant_id_offset, t_Intercept, t_trial_type, t_group:trial_type, t_1|participant_id_sigma, t_1|participant_id_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 5_000 tune and 5_000 draw iterations (20_000 + 20_000 draws total) took 7814 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# 100%|████████████████████████████████████| 20000/20000 [00:30<00:00, 654.59it/s]

# %%
# save inference data
m_int_trace.to_netcdf('models_hssm/m_int_10000.nc')
# Out:
# 'models_hssm/m_int_10000.nc'

# %%
m_int.summary()
# Out:
#                                   mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# a_1|participant_id_offset[100]   0.390  0.510  -0.588    1.327      0.005
# a_1|participant_id_offset[101]  -0.793  0.495  -1.699    0.142      0.011
# a_1|participant_id_offset[102]   1.054  0.562  -0.011    2.142      0.056
# a_1|participant_id_offset[103]   1.445  0.521   0.439    2.382      0.006
# a_1|participant_id_offset[104]   1.047  0.515   0.051    1.975      0.006
# ...                                ...    ...     ...      ...        ...
# t_1|participant_id_offset[7014] -0.116  0.364  -0.714    0.760      0.086
# t_1|participant_id_offset[7015] -0.737  0.188  -1.088   -0.388      0.010
# t_1|participant_id_offset[7019]  0.108  0.157  -0.191    0.401      0.009
# t_1|participant_id_offset[7036] -0.880  0.165  -1.188   -0.573      0.010
# a_trial_type[incongruent]        0.023  0.011   0.003    0.043      0.001
#
#                                  mcse_sd  ess_bulk  ess_tail  r_hat
# a_1|participant_id_offset[100]     0.004    9865.0   13333.0   1.00
# a_1|participant_id_offset[101]     0.008    2107.0    6670.0   1.00
# a_1|participant_id_offset[102]     0.040     116.0      89.0   1.03
# a_1|participant_id_offset[103]     0.004    7889.0   13917.0   1.00
# a_1|participant_id_offset[104]     0.004    6676.0   12666.0   1.00
# ...                                  ...       ...       ...    ...
# t_1|participant_id_offset[7014]    0.062      33.0      26.0   1.09
# t_1|participant_id_offset[7015]    0.007     360.0     767.0   1.02
# t_1|participant_id_offset[7019]    0.006     344.0     359.0   1.02
# t_1|participant_id_offset[7036]    0.007     299.0     358.0   1.02
# a_trial_type[incongruent]          0.000     440.0     730.0   1.00
#
# [547 rows x 9 columns]

# %%
m_int.plot_trace()

# %%
params = ["~id"]
az.summary(m_int_trace, var_names=params, filter_vars="regex", hdi_prob=.8)
# Out:
#                                         mean     sd  hdi_10%  hdi_90%  \
# a_Intercept                            0.392  0.012    0.377    0.408
# t_Intercept                            0.421  0.014    0.403    0.439
# v_group:trial_type[SI, congruent]      0.014  0.106   -0.116    0.153
# v_group:trial_type[SI, incongruent]    0.025  0.102   -0.108    0.153
# v_group:trial_type[rMDD, congruent]   -0.018  0.095   -0.136    0.107
# v_group:trial_type[rMDD, incongruent]  0.044  0.091   -0.077    0.157
# t_trial_type[incongruent]              0.060  0.005    0.055    0.068
# v_trial_type[incongruent]             -0.018  0.092   -0.138    0.098
# a_group:trial_type[SI, congruent]      0.044  0.020    0.018    0.069
# a_group:trial_type[SI, incongruent]    0.037  0.020    0.010    0.061
# a_group:trial_type[rMDD, congruent]    0.018  0.017   -0.004    0.039
# a_group:trial_type[rMDD, incongruent]  0.005  0.017   -0.016    0.028
# a_trial_type[incongruent]              0.023  0.011    0.009    0.036
# v_Intercept                            0.026  0.073   -0.065    0.121
# t_group:trial_type[SI, congruent]      0.009  0.024   -0.022    0.039
# t_group:trial_type[SI, incongruent]    0.021  0.024   -0.008    0.054
# t_group:trial_type[rMDD, congruent]    0.023  0.021   -0.003    0.050
# t_group:trial_type[rMDD, incongruent]  0.046  0.021    0.019    0.072
# z_Intercept                            0.497  0.005    0.490    0.504
#
#                                        mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# a_Intercept                                0.000    0.000    2757.0    6673.0
# t_Intercept                                0.001    0.000     539.0    1098.0
# v_group:trial_type[SI, congruent]          0.001    0.001   19449.0   15515.0
# v_group:trial_type[SI, incongruent]        0.001    0.001   25573.0   15769.0
# v_group:trial_type[rMDD, congruent]        0.001    0.001   20203.0   15260.0
# v_group:trial_type[rMDD, incongruent]      0.001    0.001   23772.0   15253.0
# t_trial_type[incongruent]                  0.000    0.000     221.0     312.0
# v_trial_type[incongruent]                  0.001    0.001   18445.0   14438.0
# a_group:trial_type[SI, congruent]          0.000    0.000    3774.0    6816.0
# a_group:trial_type[SI, incongruent]        0.000    0.000    1934.0    7581.0
# a_group:trial_type[rMDD, congruent]        0.000    0.000    3291.0    7703.0
# a_group:trial_type[rMDD, incongruent]      0.000    0.000    2344.0    5014.0
# a_trial_type[incongruent]                  0.001    0.000     440.0     730.0
# v_Intercept                                0.001    0.000   17095.0   14195.0
# t_group:trial_type[SI, congruent]          0.001    0.001     646.0     913.0
# t_group:trial_type[SI, incongruent]        0.001    0.001     565.0     867.0
# t_group:trial_type[rMDD, congruent]        0.001    0.001     431.0     565.0
# t_group:trial_type[rMDD, incongruent]      0.001    0.001     439.0     719.0
# z_Intercept                                0.000    0.000    5747.0   12904.0
#
#                                        r_hat
# a_Intercept                             1.00
# t_Intercept                             1.01
# v_group:trial_type[SI, congruent]       1.00
# v_group:trial_type[SI, incongruent]     1.00
# v_group:trial_type[rMDD, congruent]     1.00
# v_group:trial_type[rMDD, incongruent]   1.00
# t_trial_type[incongruent]               1.01
# v_trial_type[incongruent]               1.00
# a_group:trial_type[SI, congruent]       1.00
# a_group:trial_type[SI, incongruent]     1.00
# a_group:trial_type[rMDD, congruent]     1.00
# a_group:trial_type[rMDD, incongruent]   1.00
# a_trial_type[incongruent]               1.00
# v_Intercept                             1.00
# t_group:trial_type[SI, congruent]       1.01
# t_group:trial_type[SI, incongruent]     1.01
# t_group:trial_type[rMDD, congruent]     1.00
# t_group:trial_type[rMDD, incongruent]   1.00
# z_Intercept                             1.00

# %%
az.plot_forest(m_int_trace, var_names=params, filter_vars="regex", hdi_prob=.8)
# Out:
# array([<Axes: title={'center': '80.0% HDI'}>], dtype=object)
